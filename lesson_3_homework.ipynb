# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# %%
img = cv2.imread('data/1472042719_15.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
# Create a blurred (unsharp) version of the original image (you can use Gaussian blurring)
original = img/255
unsharp = cv2.GaussianBlur(original, ksize=(9,5), sigmaX=4)
plt.imshow(unsharp)

# %%
# Create the difference image (original − unsharp)
# Note: Remember that you are working with uint8 data types. Any addition or substractions
# might result in overflow or underflow, respectively. You can prevent this by casting the images to float.
diff = np.clip(original - unsharp, 0, 1)

# %%
# Apply USM to get the resulting image using `sharpened = original + (original − unsharp) × amount`
# Note: Again, take care of underflows/overflows if necessary.
large_amount = 10

sharpened = np.clip(original + (original - unsharp) * large_amount, 0, 1)
plt.imshow(sharpened)

# %%
small_amount = 0.1

sharpened = np.clip(original + (original - unsharp) * small_amount, 0, 1)
plt.imshow(sharpened)

# %%
# Answers:
# 1. If amount is too large, we can se noise
# 2. If amount is too small, we'll not see we will not see much difference compared to the original
